# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

if os.getcwd().endswith('notebooks'):
    # Move up one level to the project root
    os.chdir('..') 

print(f"Current Working Directory: {os.getcwd()}")
# Out:
# Current Working Directory: /home/hsozer/Projects/DeepLearning/recipe_bot

# %%
import pandas as pd
from scripts.preprocessing import parse_nutrition, calculate_nutrition_mass, filter_outliers, parse_lists

# --- Configuration ---
RAW_DATA_PATH = "data/food-com-recipes-and-user-interactions/RAW_recipes.csv"
PROCESSED_PATH = "data/processed/clean_recipes.pkl"

# %%
print("⏳ Loading raw data...")
df = pd.read_csv(RAW_DATA_PATH)

print(f"✅ Loaded successfully!")
print(f"   Raw Shape: {df.shape}")
# Out:
# ⏳ Loading raw data...
# ✅ Loaded successfully!
#    Raw Shape: (231637, 12)

# %%
# Parse Nutrition Columns
print("⏳ Parsing nutrition columns...")
df = parse_nutrition(df)

# Calculate Mass
print("⏳ Calculating nutrition mass...")
df = calculate_nutrition_mass(df)

# 3. Filter Junk
print("⏳ Removing outliers...")
df_clean = filter_outliers(df)
print(f"   Cleaned Shape: {df_clean.shape} (Dropped {len(df) - len(df_clean)} rows)")

# Parse Text Lists
# We pass the specific columns we want to convert from strings to lists
print("⏳ Parsing text lists (ingredients, tags, steps)...")
df_final = parse_lists(df_clean, columns=['ingredients', 'tags', 'steps'])

# Preview
display(df_final.head(3))
# Out:
# ⏳ Parsing nutrition columns...
# ⏳ Calculating nutrition mass...
# ⏳ Removing outliers (physics filter)...
#    - Removed 1 items due to missing essential fields.
#    Cleaned Shape: (225342, 25) (Dropped 6295 rows)
# ⏳ Parsing text lists (ingredients, tags, steps)...
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
#
#                                                 tags  n_steps  \
# 0  [60-minutes-or-less, time-to-make, course, mai...       11
# 1  [30-minutes-or-less, time-to-make, course, mai...        9
# 2  [time-to-make, course, preparation, main-dish,...        6
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
#
#                                          ingredients  ...  protein_pdv  \
# 0  [winter squash, mexican seasoning, mixed spice...  ...          2.0
# 1  [prepared pizza crust, sausage patty, eggs, mi...  ...         22.0
# 2  [ground beef, yellow onions, diced tomatoes, t...  ...         39.0
#
#    sat_fat_pdv  carbs_pdv  total_fat_g  sugar_g  sodium_mg  protein_g  \
# 0          0.0        4.0          0.0      6.5        0.0        1.0
# 1         35.0        1.0         11.7      0.0      408.0       11.0
# 2         27.0        5.0         14.3     16.0     1152.0       19.5
#
#    sat_fat_g  carbs_g  estimated_weight_g
# 0        0.0     12.0                13.0
# 1        7.0      3.0                25.7
# 2        5.4     15.0                48.8
#
# [3 rows x 25 columns]

# %%
# Final Cleanup
cols_to_drop = [
    'contributor_id',  # User ID of uploader
    'submitted',       # Date uploaded
    'estimated_weight_g' # used for filtering
]

print(f"⏳ Dropping unused columns: {cols_to_drop}...")
df_final = df_final.drop(columns=cols_to_drop, errors='ignore')

# Save
print("💾 Saving to Pickle...")
os.makedirs(os.path.dirname(PROCESSED_PATH), exist_ok=True)

df_final.to_pickle(PROCESSED_PATH)

print(f"✅ Pipeline Finished! Saved to {PROCESSED_PATH}")
print(f"   Final Columns: {list(df_final.columns)}")
display(df_final.head(3))
# Out:
# ⏳ Dropping unused columns: ['contributor_id', 'submitted', 'estimated_weight_g']...
# 💾 Saving to Pickle...
# ✅ Pipeline Finished! Saved to data/processed/clean_recipes.pkl
#    Final Columns: ['name', 'id', 'minutes', 'tags', 'n_steps', 'steps', 'description', 'ingredients', 'n_ingredients', 'calories', 'total_fat_pdv', 'sugar_pdv', 'sodium_pdv', 'protein_pdv', 'sat_fat_pdv', 'carbs_pdv', 'total_fat_g', 'sugar_g', 'sodium_mg', 'protein_g', 'sat_fat_g', 'carbs_g']
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
#
#                                                 tags  n_steps  \
# 0  [60-minutes-or-less, time-to-make, course, mai...       11
# 1  [30-minutes-or-less, time-to-make, course, mai...        9
# 2  [time-to-make, course, preparation, main-dish,...        6
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
#
#                                          ingredients  n_ingredients  calories  \
# 0  [winter squash, mexican seasoning, mixed spice...              7      51.5
# 1  [prepared pizza crust, sausage patty, eggs, mi...              6     173.4
# 2  [ground beef, yellow onions, diced tomatoes, t...             13     269.8
#
#    ...  sodium_pdv  protein_pdv  sat_fat_pdv  carbs_pdv  total_fat_g  sugar_g  \
# 0  ...         0.0          2.0          0.0        4.0          0.0      6.5
# 1  ...        17.0         22.0         35.0        1.0         11.7      0.0
# 2  ...        48.0         39.0         27.0        5.0         14.3     16.0
#
#    sodium_mg  protein_g  sat_fat_g  carbs_g
# 0        0.0        1.0        0.0     12.0
# 1      408.0       11.0        7.0      3.0
# 2     1152.0       19.5        5.4     15.0
#
# [3 rows x 22 columns]

# %%
from collections import Counter

# Tag Analysis
all_tags = [tag for tags_list in df_final['tags'] for tag in tags_list]
tag_counts = Counter(all_tags)

print(f"\n📊 Total unique tags found: {len(tag_counts):,}")
print("-" * 40)
print("🔥 Top 150 Most Common Tags:")
print("-" * 40)

for i, (tag, count) in enumerate(tag_counts.most_common(150), 1):
    # Print in 3 columns to save space
    print(f"{i:2}. {tag:<25} ({count:,})")
# Out:
# 📊 Total unique tags found: 552
# ----------------------------------------
# 🔥 Top 150 Most Common Tags:
# ----------------------------------------
#  1. preparation               (224,268)
#  2. time-to-make              (219,084)
#  3. course                    (212,400)
#  4. main-ingredient           (166,846)
#  5. dietary                   (160,808)
#  6. easy                      (122,543)
#  7. occasion                  (110,727)
#  8. cuisine                   (88,682)
#  9. low-in-something          (83,849)
# 10. main-dish                 (70,838)
# 11. 60-minutes-or-less        (69,574)
# 12. equipment                 (68,583)
# 13. number-of-servings        (55,966)
# 14. meat                      (55,000)
# 15. 30-minutes-or-less        (54,778)
# 16. vegetables                (53,017)
# 17. taste-mood                (51,007)
# 18. 4-hours-or-less           (48,908)
# 19. north-american            (47,131)
# 20. 3-steps-or-less           (43,336)
# 21. low-sodium                (42,248)
# 22. desserts                  (41,801)
# 23. low-carb                  (41,249)
# 24. 15-minutes-or-less        (41,172)
# 25. healthy                   (39,338)
# 26. dinner-party              (36,442)
# 27. low-cholesterol           (35,758)
# 28. low-calorie               (35,677)
# 29. beginner-cook             (34,859)
# 30. vegetarian                (34,793)
# 31. holiday-event             (33,609)
# 32. 5-ingredients-or-less     (33,520)
# 33. inexpensive               (32,058)
# 34. low-protein               (31,537)
# 35. low-saturated-fat         (30,464)
# 36. fruit                     (30,363)
# 37. american                  (30,271)
# 38. oven                      (30,240)
# 39. eggs-dairy                (29,555)
# 40. pasta-rice-and-grains     (26,823)
# 41. kid-friendly              (26,610)
# 42. side-dishes               (26,598)
# 43. healthy-2                 (26,173)
# 44. comfort-food              (25,708)
# 45. european                  (24,178)
