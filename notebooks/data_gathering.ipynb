# %%
import sys
import os
import pandas as pd
import opendatasets as od

#Data directory and dataset URL
DATA_DIR = "../data"
KAGGLE_DATASET_URL = "https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions"

#Checking data directory existence
os.makedirs(DATA_DIR, exist_ok=True)

#Downloading dataset
od.download(KAGGLE_DATASET_URL, data_dir=DATA_DIR)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions
# ...
# 100%|██████████| 267M/267M [00:00<00:00, 1.26GB/s]

# %%
import requests
from bs4 import BeautifulSoup
import time
import random

#CONFIGURATION
BASE_URL = "https://www.allrecipes.com/recipes/76/appetizers-and-snacks/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

def get_soup(url):
    try:
        response = requests.get(url, headers=HEADERS, timeout=10)
        if response.status_code == 200:
            return BeautifulSoup(response.content, 'html.parser')
    except:
        print(f"Failed to retrieve {url}")
    return None

# %%
collection_urls = []
category_urls = []
recipe_urls = []

print("Starting to scrape collection URLs...")
soup = get_soup(BASE_URL)

if soup:
    titles = soup.find_all('span', class_=['card__title', 'link__wrapper'])
    for title in titles:
        link = title.find_parent('a')

        if link:
            url = link['href']
            
            if '/recipe/' in url and url not in recipe_urls:
                print(f"Found recipe: {url}")
                recipe_urls.append(url)

            elif '/recipes/' in url and url not in category_urls:
                print(f"Found recipe category: {url}")
                category_urls.append(url)

            elif '/gallery/' in url and url not in collection_urls:
                print(f"Found recipe collection: {url}")
                collection_urls.append(url)

            else:
                print(f"Unknown or already in use link: {url}")


print(f"Total collections found: {len(collection_urls)}")
print(f"Total categories found: {len(category_urls)}")
print(f"Total recipes found: {len(recipe_urls)}")
# Out:
# Starting to scrape collection URLs...
# Unknown link type: #main
# Unknown link type: #
# Unknown link type: #
# Unknown link type: #
# Found recipe category: https://www.allrecipes.com/recipes/
# Found recipe category: https://www.allrecipes.com/recipes/102/appetizers-and-snacks/antipasto/
# Found recipe category: https://www.allrecipes.com/recipes/104/appetizers-and-snacks/cheese/
# Found recipe category: https://www.allrecipes.com/recipes/105/appetizers-and-snacks/dips-and-spreads/
# Found recipe category: https://www.allrecipes.com/recipes/106/appetizers-and-snacks/fruit/
# Found recipe category: https://www.allrecipes.com/recipes/107/appetizers-and-snacks/meat-and-poultry/
# Found recipe category: https://www.allrecipes.com/recipes/108/appetizers-and-snacks/seafood/
# Found recipe category: https://www.allrecipes.com/recipes/109/appetizers-and-snacks/vegetable/
# Found recipe category: https://www.allrecipes.com/recipes/110/appetizers-and-snacks/deviled-eggs/
# ...
