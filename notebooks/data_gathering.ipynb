# %%
import sys
import os
import pandas as pd
import opendatasets as od

#Data directory and dataset URL
DATA_DIR = "../data"
KAGGLE_DATASET_URL = "https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions"

#Checking data directory existence
os.makedirs(DATA_DIR, exist_ok=True)

#Downloading dataset
od.download(KAGGLE_DATASET_URL, data_dir=DATA_DIR)
# Out:
# Skipping, found downloaded files in "../data/food-com-recipes-and-user-interactions" (use force=True to force download)

# %%
if os.getcwd().endswith('notebooks'):
    # Move up one level to the project root
    os.chdir('..') 

print(f"Current Working Directory: {os.getcwd()}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Current Working Directory: /home/hsozer/Projects/DeepLearning/recipe_bot
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scripts.scraper import category_crawler, final_category_urls, visited_urls
BASE_URL = "https://www.allrecipes.com/recipes/76/appetizers-and-snacks/"

visited_urls.clear()
final_category_urls.clear()

print("Starting category crawl...")
category_crawler(BASE_URL)

print("-" * 30)
print("Crawling completed.")
print(f"Leaf Categories Found: {len(final_category_urls)}")

print("\nSample Leaves:")
for url in list(final_category_urls)[:5]:
    print(url)
# Out:
# Starting category crawl...
# Leaf category found: https://www.allrecipes.com/recipes/102/appetizers-and-snacks/antipasto/
# Leaf category found: https://www.allrecipes.com/recipes/1228/appetizers-and-snacks/cheese/nachos/
# Leaf category found: https://www.allrecipes.com/recipes/17024/appetizers-and-snacks/cheese/baked-brie/
# Leaf category found: https://www.allrecipes.com/recipes/433/appetizers-and-snacks/cheese/cheese-fondue/
# Leaf category found: https://www.allrecipes.com/recipes/17814/appetizers-and-snacks/dips-and-spreads/spinach-dips/spinach-and-artichoke/
# Leaf category found: https://www.allrecipes.com/recipes/1243/appetizers-and-snacks/dips-and-spreads/crab-dip/
# Leaf category found: https://www.allrecipes.com/recipes/1244/appetizers-and-snacks/dips-and-spreads/shrimp-dip/
# Leaf category found: https://www.allrecipes.com/recipes/1281/appetizers-and-snacks/dips-and-spreads/hummus/
# ...
